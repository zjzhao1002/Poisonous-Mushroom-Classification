# %% [markdown]
# <a href="https://www.kaggle.com/code/zjzhao1002/poisonous-mushroom-classification-nn?scriptVersionId=194232138" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # 1. Basic Information of Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df_train = pd.read_csv("/kaggle/input/playground-series-s4e8/train.csv")
print(df_train.head())
# Out:
#    id class  cap-diameter cap-shape cap-surface cap-color  \
# 0   0     e          8.80         f           s         u
# 1   1     p          4.51         x           h         o
# 2   2     e          6.94         f           s         b
# 3   3     e          3.88         f           y         g
# 4   4     e          5.85         x           l         w
#
#   does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# 0                    f               a            c          w  ...
# 1                    f               a            c          n  ...
# 2                    f               x            c          w  ...
# 3                    f               s          NaN          g  ...
# 4                    f               d          NaN          w  ...
#
#    stem-root  stem-surface stem-color veil-type veil-color has-ring ring-type  \
# 0        NaN           NaN          w       NaN        NaN        f         f
# 1        NaN             y          o       NaN        NaN        t         z
# 2        NaN             s          n       NaN        NaN        f         f
# 3        NaN           NaN          w       NaN        NaN        f         f
# 4        NaN           NaN          w       NaN        NaN        f         f
#
#   spore-print-color habitat season
# 0               NaN       d      a
# 1               NaN       d      w
# 2               NaN       l      w
# 3               NaN       d      u
# 4               NaN       g      a
#
# [5 rows x 22 columns]

# %%
df_train.columns
# Out:
# Index(['id', 'class', 'cap-diameter', 'cap-shape', 'cap-surface', 'cap-color',
#        'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing', 'gill-color',
#        'stem-height', 'stem-width', 'stem-root', 'stem-surface', 'stem-color',
#        'veil-type', 'veil-color', 'has-ring', 'ring-type', 'spore-print-color',
#        'habitat', 'season'],
#       dtype='object')

# %%
df_train.isnull().sum()
# Out:
# id                            0
# class                         0
# cap-diameter                  4
# cap-shape                    40
# cap-surface              671023
# cap-color                    12
# does-bruise-or-bleed          8
# gill-attachment          523936
# gill-spacing            1258435
# gill-color                   57
# stem-height                   0
# stem-width                    0
# stem-root               2757023
# stem-surface            1980861
# stem-color                   38
# veil-type               2957493
# veil-color              2740947
# has-ring                     24
# ring-type                128880
# spore-print-color       2849682
# habitat                      45
# season                        0
# dtype: int64

# %%
df_train.shape
# Out:
# (3116945, 22)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3116945 entries, 0 to 3116944
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   class                 object
#  2   cap-diameter          float64
#  3   cap-shape             object
#  4   cap-surface           object
#  5   cap-color             object
#  6   does-bruise-or-bleed  object
#  7   gill-attachment       object
#  8   gill-spacing          object
#  9   gill-color            object
#  10  stem-height           float64
#  11  stem-width            float64
#  12  stem-root             object
#  13  stem-surface          object
#  14  stem-color            object
#  15  veil-type             object
#  16  veil-color            object
#  17  has-ring              object
#  18  ring-type             object
#  19  spore-print-color     object
#  20  habitat               object
#  21  season                object
# dtypes: float64(3), int64(1), object(18)
# memory usage: 523.2+ MB

# %% [markdown]
# # 2. Data Cleaning

# %% [markdown]
# We have seen that there are many missing values in the data, so we have to clean data before training our model.

# %%
num_columns = df_train.select_dtypes(include='float64').columns
cat_columns = df_train.select_dtypes(include='object').columns

# %% [markdown]
# For the numeric columns, we impute the median of corresponding column.

# %%
for column in num_columns:
    df_train[column] = df_train[column].fillna(float(df_train[column].median()))

# %% [markdown]
# For the catagorical columns, we have seen some columns have too many missing values. If a column has missing values more than 60% of total, we may say that this column can be removed safely.

# %%
nan_count = df_train.isna().sum()
total_count = df_train.shape[0]
nan_ratio = nan_count / total_count
high_nan_ratio = nan_ratio[nan_ratio > 0.6]
print(high_nan_ratio)
# Out:
# stem-root            0.884527
# stem-surface         0.635514
# veil-type            0.948843
# veil-color           0.879370
# spore-print-color    0.914255
# dtype: float64

# %%
df_train_new = df_train.drop(['id', 'stem-root', 'stem-surface', 'veil-type', 'veil-color', 'spore-print-color'], axis=1)

# %% [markdown]
# We fill 'none' to the remained columns.

# %%
cat_columns = df_train_new.select_dtypes(include='object').columns

for column in cat_columns:
    df_train_new[column].fillna('none', inplace=True)
# Out:
# /tmp/ipykernel_36/2479688860.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train_new[column].fillna('none', inplace=True)

# %% [markdown]
# Now we can check if there is any missing value in our data.

# %%
print(df_train_new.isna().sum())
# Out:
# class                   0
# cap-diameter            0
# cap-shape               0
# cap-surface             0
# cap-color               0
# does-bruise-or-bleed    0
# gill-attachment         0
# gill-spacing            0
# gill-color              0
# stem-height             0
# stem-width              0
# stem-color              0
# has-ring                0
# ring-type               0
# habitat                 0
# season                  0
# dtype: int64

# %% [markdown]
# Now we look into the unique values in catagorical columns.

# %%
df_train_new[cat_columns].nunique()
# Out:
# class                    2
# cap-shape               75
# cap-surface             84
# cap-color               79
# does-bruise-or-bleed    27
# gill-attachment         79
# gill-spacing            49
# gill-color              64
# stem-color              60
# has-ring                24
# ring-type               41
# habitat                 53
# season                   4
# dtype: int64

# %% [markdown]
# Obviously, thera are too many values in these columns except the 'class' and 'season' columns. We want to collect the values that appear less frequently, and treat them as 'noise'.

# %%
def remove_noise(df):
    cat_columns = df.select_dtypes(include='object').columns
    for column in cat_columns:
        count = df[column].value_counts()
        less_freq = count[count<101].index
        df[column] = df[column].apply(lambda x: 'noise' if x in less_freq else x)
    return df

# %%
df_train_new = remove_noise(df_train_new)

# %%
df_train_new[cat_columns].nunique()
# Out:
# class                    2
# cap-shape                8
# cap-surface             13
# cap-color               13
# does-bruise-or-bleed     3
# gill-attachment          9
# gill-spacing             5
# gill-color              13
# stem-color              14
# has-ring                 3
# ring-type               10
# habitat                  9
# season                   4
# dtype: int64

# %% [markdown]
# It seems much better now. We make some plots to see the distributions.

# %%
def make_barplot(df):
    cat_columns = df.select_dtypes(include='object').columns
    for column in cat_columns:
        plt.figure(figsize=(10, 5))
        uni_count = df[column].value_counts()
        sns.barplot(x=uni_count.index, y=uni_count.values)
        plt.ylabel(f"Count of '{column}'")
        plt.xlabel(f"{column}")
        plt.title(f"Count of unique categories in column '{column}'")
        plt.show()

# %%
make_barplot(df_train_new)

# %% [markdown]
# We can see that most columns have replaced the 'none' by the 'noise'. However, we also see that the 'none' is the largest fraction of the 'cap-surface' column. This may introduce some uncertainties.
#
# We can also look at the distributions of the numeric columns:

# %%
def make_hist(df):
    num_columns = df.select_dtypes(include='float64').columns
    for column in num_columns:
        pvalue = df[df['class']=='p'][column].to_numpy()
        evalue = df[df['class']=='e'][column].to_numpy()
        fig, ax = plt.subplots(figsize=(10,5))
        ax.hist(pvalue, bins=30, range=[0, 60], density=True, label='p')
        ax.hist(evalue, bins=30, range=[0, 60], density=True, label='e')
        ax.legend()
        ax.set_xlabel(f'{column}')
        ax.set_ylabel('Fraction of data')
        plt.show()

# %%
make_hist(df_train_new)

# %% [markdown]
# It seems that the poisonous mushrooms tend to have smaller cap-diameter and stem-width than the editable mushrooms.

# %% [markdown]
# # 3. Encoding

# %% [markdown]
# The next step is encoding the data for training.

# %%
X_train = df_train_new.drop(['class'], axis=1)
y_train = df_train_new['class']

# %% [markdown]
# We scale the numeric data by the StandardScaler and encode the catagorical data by the OrdinalEncoder.

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler, OrdinalEncoder

def preprocess(df):
    cat_columns = df.select_dtypes(include='object').columns
    num_columns = df.select_dtypes(include='float64').columns
    
    scaler = StandardScaler()
    df[num_columns] = scaler.fit_transform(df[num_columns])
    
    encoder = OrdinalEncoder()
    df[cat_columns] = encoder.fit_transform(df[cat_columns].astype(str))
    
    return df

# %%
X_train = preprocess(X_train)

# %%
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_train
# Out:
# array([0, 1, 0, ..., 1, 0, 1])

# %% [markdown]
# # 4. Model

# %%
from sklearn.model_selection import train_test_split

X_train_new, X_val, y_train_new, y_val = train_test_split(
    X_train,
    y_train,
    test_size=0.20,
    random_state=1
)

# %% [markdown]
# We use a neural networks model in this case.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Input,BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Input(shape=(X_train_new.shape[1],)),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),  
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),  
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),  
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),  
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),  
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),  
    Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 256)            │         4,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 135,361 (528.75 KB)
#  Trainable params: 133,569 (521.75 KB)
#  Non-trainable params: 1,792 (7.00 KB)

# %%
adam = Adam(learning_rate = 0.001)
model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=10, min_lr=1e-6)

# %%
history = model.fit(
    X_train_new, 
    y_train_new,
    epochs=50, 
    batch_size=512,
    validation_data=(X_val, y_val),
    callbacks = [early_stopping, reduce_lr],
)
# Out:
# Epoch 1/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.9202 - loss: 0.1978 - val_accuracy: 0.9843 - val_loss: 0.0620 - learning_rate: 0.0010
# Epoch 2/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9810 - loss: 0.0731 - val_accuracy: 0.9860 - val_loss: 0.0563 - learning_rate: 0.0010
# Epoch 3/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.9836 - loss: 0.0643 - val_accuracy: 0.9872 - val_loss: 0.0521 - learning_rate: 0.0010
# Epoch 4/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9845 - loss: 0.0610 - val_accuracy: 0.9880 - val_loss: 0.0495 - learning_rate: 0.0010
# Epoch 5/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9850 - loss: 0.0594 - val_accuracy: 0.9881 - val_loss: 0.0491 - learning_rate: 0.0010
# Epoch 6/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9858 - loss: 0.0574 - val_accuracy: 0.9886 - val_loss: 0.0480 - learning_rate: 0.0010
# Epoch 7/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9861 - loss: 0.0555 - val_accuracy: 0.9889 - val_loss: 0.0472 - learning_rate: 0.0010
# Epoch 8/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9863 - loss: 0.0551 - val_accuracy: 0.9887 - val_loss: 0.0472 - learning_rate: 0.0010
# Epoch 9/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9868 - loss: 0.0540 - val_accuracy: 0.9891 - val_loss: 0.0463 - learning_rate: 0.0010
# Epoch 10/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9870 - loss: 0.0530 - val_accuracy: 0.9891 - val_loss: 0.0460 - learning_rate: 0.0010
# Epoch 11/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.9871 - loss: 0.0528 - val_accuracy: 0.9893 - val_loss: 0.0461 - learning_rate: 0.0010
# Epoch 12/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9874 - loss: 0.0520 - val_accuracy: 0.9894 - val_loss: 0.0454 - learning_rate: 0.0010
# Epoch 13/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.9875 - loss: 0.0518 - val_accuracy: 0.9897 - val_loss: 0.0449 - learning_rate: 0.0010
# Epoch 14/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9876 - loss: 0.0512 - val_accuracy: 0.9895 - val_loss: 0.0455 - learning_rate: 0.0010
# Epoch 15/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.9877 - loss: 0.0509 - val_accuracy: 0.9897 - val_loss: 0.0444 - learning_rate: 0.0010
# Epoch 16/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9879 - loss: 0.0502 - val_accuracy: 0.9897 - val_loss: 0.0450 - learning_rate: 0.0010
# Epoch 17/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.9879 - loss: 0.0508 - val_accuracy: 0.9899 - val_loss: 0.0439 - learning_rate: 0.0010
# Epoch 18/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9879 - loss: 0.0501 - val_accuracy: 0.9900 - val_loss: 0.0441 - learning_rate: 0.0010
# Epoch 19/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9882 - loss: 0.0493 - val_accuracy: 0.9901 - val_loss: 0.0436 - learning_rate: 0.0010
# Epoch 20/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.9881 - loss: 0.0495 - val_accuracy: 0.9901 - val_loss: 0.0433 - learning_rate: 0.0010
# Epoch 21/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9884 - loss: 0.0488 - val_accuracy: 0.9901 - val_loss: 0.0433 - learning_rate: 0.0010
# Epoch 22/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9883 - loss: 0.0490 - val_accuracy: 0.9897 - val_loss: 0.0443 - learning_rate: 0.0010
# Epoch 23/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9884 - loss: 0.0488 - val_accuracy: 0.9902 - val_loss: 0.0435 - learning_rate: 0.0010
# Epoch 24/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9885 - loss: 0.0484 - val_accuracy: 0.9902 - val_loss: 0.0433 - learning_rate: 0.0010
# Epoch 25/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9885 - loss: 0.0488 - val_accuracy: 0.9902 - val_loss: 0.0434 - learning_rate: 0.0010
# Epoch 26/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9886 - loss: 0.0486 - val_accuracy: 0.9902 - val_loss: 0.0428 - learning_rate: 0.0010
# Epoch 27/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9885 - loss: 0.0484 - val_accuracy: 0.9900 - val_loss: 0.0443 - learning_rate: 0.0010
# Epoch 28/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9888 - loss: 0.0476 - val_accuracy: 0.9903 - val_loss: 0.0434 - learning_rate: 0.0010
# Epoch 29/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9887 - loss: 0.0478 - val_accuracy: 0.9903 - val_loss: 0.0428 - learning_rate: 0.0010
# Epoch 30/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.9887 - loss: 0.0478 - val_accuracy: 0.9904 - val_loss: 0.0425 - learning_rate: 0.0010
# Epoch 31/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9888 - loss: 0.0474 - val_accuracy: 0.9904 - val_loss: 0.0427 - learning_rate: 0.0010
# Epoch 32/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.9889 - loss: 0.0474 - val_accuracy: 0.9903 - val_loss: 0.0428 - learning_rate: 0.0010
# Epoch 33/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.9890 - loss: 0.0469 - val_accuracy: 0.9904 - val_loss: 0.0427 - learning_rate: 0.0010
# Epoch 34/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.9889 - loss: 0.0476 - val_accuracy: 0.9906 - val_loss: 0.0423 - learning_rate: 0.0010
# Epoch 35/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9890 - loss: 0.0473 - val_accuracy: 0.9905 - val_loss: 0.0428 - learning_rate: 0.0010
# Epoch 36/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.9889 - loss: 0.0473 - val_accuracy: 0.9904 - val_loss: 0.0427 - learning_rate: 0.0010
# Epoch 37/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9889 - loss: 0.0473 - val_accuracy: 0.9906 - val_loss: 0.0420 - learning_rate: 0.0010
# Epoch 38/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9890 - loss: 0.0473 - val_accuracy: 0.9904 - val_loss: 0.0428 - learning_rate: 0.0010
# Epoch 39/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9892 - loss: 0.0462 - val_accuracy: 0.9903 - val_loss: 0.0426 - learning_rate: 0.0010
# Epoch 40/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.9890 - loss: 0.0466 - val_accuracy: 0.9906 - val_loss: 0.0421 - learning_rate: 0.0010
# Epoch 41/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9892 - loss: 0.0465 - val_accuracy: 0.9905 - val_loss: 0.0423 - learning_rate: 0.0010
# Epoch 42/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9891 - loss: 0.0464 - val_accuracy: 0.9906 - val_loss: 0.0420 - learning_rate: 0.0010
# Epoch 43/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9892 - loss: 0.0466 - val_accuracy: 0.9905 - val_loss: 0.0425 - learning_rate: 0.0010
# Epoch 44/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9892 - loss: 0.0461 - val_accuracy: 0.9906 - val_loss: 0.0426 - learning_rate: 0.0010
# Epoch 45/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9891 - loss: 0.0464 - val_accuracy: 0.9906 - val_loss: 0.0422 - learning_rate: 0.0010
# Epoch 46/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9893 - loss: 0.0461 - val_accuracy: 0.9906 - val_loss: 0.0419 - learning_rate: 0.0010
# Epoch 47/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.9893 - loss: 0.0460 - val_accuracy: 0.9905 - val_loss: 0.0421 - learning_rate: 0.0010
# Epoch 48/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9894 - loss: 0.0460 - val_accuracy: 0.9906 - val_loss: 0.0418 - learning_rate: 0.0010
# Epoch 49/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.9891 - loss: 0.0466 - val_accuracy: 0.9907 - val_loss: 0.0426 - learning_rate: 0.0010
# Epoch 50/50
# 4871/4871 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.9892 - loss: 0.0465 - val_accuracy: 0.9907 - val_loss: 0.0418 - learning_rate: 0.0010

# %%
def plot(history, arr):
    fig, ax = plt.subplots(1, 2, figsize=(20, 5))
    for idx in range(2):
        ax[idx].plot(history.history[arr[idx][0]])
        ax[idx].plot(history.history[arr[idx][1]])
        ax[idx].legend([arr[idx][0], arr[idx][1]],fontsize=18)
        ax[idx].set_xlabel('Epoch',fontsize=16)
        ax[idx].set_ylabel(f'{arr[idx][0]}',fontsize=16)
        # ax[idx].set_title(arr[idx][0] + ' X ' + arr[idx][1],fontsize=16)

# %%
plot(history, [['loss', 'val_loss'], ['accuracy', 'val_accuracy']])

# %% [markdown]
# # 5. Prediction

# %% [markdown]
# We do the same things to the test data and make predictions.

# %%
df_test = pd.read_csv("/kaggle/input/playground-series-s4e8/test.csv")
num_columns = df_test.select_dtypes(include='float64').columns
cat_columns = df_test.select_dtypes(include='object').columns

for column in num_columns:
    df_test[column] = df_test[column].fillna(float(df_test[column].median()))

df_test_new = df_test.drop(['id', 'stem-root', 'stem-surface', 'veil-type', 'veil-color', 'spore-print-color'], axis=1)

cat_columns = df_test_new.select_dtypes(include='object').columns

for column in cat_columns:
    df_test_new[column].fillna('none', inplace=True)

df_test_new = remove_noise(df_test_new)
X_test = df_test_new
X_test = preprocess(X_test)
X_test.head()
# Out:
# /tmp/ipykernel_36/3127810417.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test_new[column].fillna('none', inplace=True)
#    cap-diameter  cap-shape  cap-surface  cap-color  does-bruise-or-bleed  \
# 0      0.498097        7.0          8.0        5.0                   2.0
# 1      0.126735        4.0         10.0        7.0                   0.0
# 2     -0.919055        0.0          2.0        5.0                   0.0
# 3     -0.605318        7.0         10.0        5.0                   0.0
# 4     -0.029067        7.0          3.0       12.0                   0.0
#
#    gill-attachment  gill-spacing  gill-color  stem-height  stem-width  \
# 0              5.0           4.0        11.0     1.772335    0.737221
# 1              5.0           0.0        12.0    -1.880901   -0.049181
# 2              5.0           0.0         5.0    -0.061693   -0.988666
# 3              7.0           0.0         5.0    -0.506306   -0.325718
# 4              6.0           4.0        12.0     0.142088    0.315009
#
#    stem-color  has-ring  ring-type  habitat  season
# 0        12.0       2.0        2.0      0.0     0.0
# 1         6.0       0.0        1.0      0.0     0.0
# 2         6.0       0.0        1.0      0.0     1.0
# 3        12.0       2.0        9.0      0.0     2.0
# 4        13.0       2.0        6.0      0.0     2.0

# %% [markdown]
# Finally, we generate the file for submission.

# %%
results = model.predict(X_test)
submission = pd.read_csv("/kaggle/input/playground-series-s4e8/sample_submission.csv")
submission['class'] = (results > 0.5).astype(int)
submission['class'] = submission['class'].replace({1: 'p', 0: 'e'})
submission.to_csv('submission.csv', index=False)
# Out:
# 64937/64937 ━━━━━━━━━━━━━━━━━━━━ 95s 1ms/step

# %%
submission.head()
# Out:
#         id class
# 0  3116945     e
# 1  3116946     p
# 2  3116947     p
# 3  3116948     p
# 4  3116949     e
